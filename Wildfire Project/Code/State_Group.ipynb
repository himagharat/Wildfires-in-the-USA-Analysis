# %%
# %matplotlib notebook

# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import scipy.stats as stats
import numpy as np
import pandas as pd

# %%
Acre_Fire = "C:\\UPenn\Wildfire Project\\Wildfire Project\\total_wildland_fires_acres.csv"

# %%
Acre_Fire_df = pd.read_csv(Acre_Fire)

# %%
Acre_Fire_df
# Out:
#     Year  Fires     Acres
# 0   2019  50477   4664364
# 1   2018  58083   8767492
# 2   2017  71499  10026086
# 3   2016  67743   5509995
# 4   2015  68151  10125149
# 5   2014  63312   3595613
# 6   2013  47579   4319546
# 7   2012  67774   9326238
# 8   2011  74126   8711367
# 9   2010  71971   3422724
# 10  2009  78792   5921786
# 11  2008  78979   5292468
# 12  2007  85705   9328045
# 13  2006  96385   9873745
# 14  2005  66753   8689389
# 15  2004  65461   8097880
# 16  2003  63629   3960842
# 17  2002  73457   7184712
# 18  2001  84079   3570911
# 19  2000  92250   7393493
# 20  1999  92487   5626093
# 21  1998  81043   1329704
# 22  1997  66196   2856959
# 23  1996  96363   6065998
# 24  1995  82234   1840546
# 25  1994  79107   4073579
# 26  1993  58810   1797574
# 27  1992  87394   2069929
# 28  1991  75754   2953578
# 29  1990  66481   4621621
# 30  1989  48949   1827310
# 31  1988  72750   5009290
# 32  1987  71300   2447296
# 33  1986  85907   2719162
# ...

# %%
Acre_plot=plt.scatter(Acre_Fire_df['Year'],Acre_Fire_df['Acres'], color='red')
plt.xlabel("years")
plt.ylabel("Acres")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Acres')

# %%
x_values = Acre_Fire_df['Year']
y_values = Acre_Fire_df['Acres']

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Years')
plt.ylabel('Acres')
print(f"The r-squared is: {rvalue**2}")
print (line_eq)
plt.show()
# Out:
# The r-squared is: 0.37368463133392654
# y = 165024.71x + -325067569.77
